# %%
# Initialize a model
from langchain_openai import ChatOpenAI

from dotenv import load_dotenv
load_dotenv()

llm = ChatOpenAI(model="gpt-4o", temperature=0, streaming=True)

# %%
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from IPython.display import Image, display


# Graph state
class State(TypedDict):
    topic: str
    joke: str
    story: str
    poem: str
    combined_output: str


# Nodes
def call_llm_1(state: State):
    """First LLM call to generate initial joke"""

    msg = llm.invoke(f"Write a joke about {state['topic']}")
    return {"joke": msg.content}


def call_llm_2(state: State):
    """Second LLM call to generate story"""

    msg = llm.invoke(f"Write a story about {state['topic']}")
    return {"story": msg.content}


def call_llm_3(state: State):
    """Third LLM call to generate poem"""

    msg = llm.invoke(f"Write a poem about {state['topic']}")
    return {"poem": msg.content}

def aggregator(state: State):
    """Combine the joke and story into a single output"""

    combined = f"Here's a story, joke, and poem about {state['topic']}!\n\n"
    combined += f"STORY:\n{state['story']}\n\n"
    combined += f"JOKE:\n{state['joke']}\n\n"
    combined += f"POEM:\n{state['poem']}"
    return {"combined_output": combined}


# Build workflow
parallel_builder = StateGraph(State)

# Add nodes
parallel_builder.add_node("call_llm_1", call_llm_1)
parallel_builder.add_node("call_llm_2", call_llm_2)
parallel_builder.add_node("call_llm_3", call_llm_3)
parallel_builder.add_node("aggregator", aggregator)

# Add edges to connect nodes
parallel_builder.add_edge(START, "call_llm_1")
parallel_builder.add_edge(START, "call_llm_2")
parallel_builder.add_edge(START, "call_llm_3")
parallel_builder.add_edge("call_llm_1", "aggregator")
parallel_builder.add_edge("call_llm_2", "aggregator")
parallel_builder.add_edge("call_llm_3", "aggregator")
parallel_builder.add_edge("aggregator", END)
parallel_workflow = parallel_builder.compile()

# Show workflow
display(Image(parallel_workflow.get_graph().draw_mermaid_png()))

# Invoke
state = parallel_workflow.invoke({"topic": "cats"})
print(state["combined_output"])
# Out:
# Here's a story, joke, and poem about cats!
#
# STORY:
# Once upon a time in the quaint village of Whiskerville, nestled between rolling hills and lush meadows, there was a peculiar phenomenon: the village was ruled by cats. Not just any cats, but a council of wise and ancient felines known as the Feline Council of Whiskerville. These cats were revered by the villagers for their wisdom, grace, and mysterious ability to bring prosperity to the land.
#
# The leader of the council was an elegant Siamese named Seraphina, whose sapphire eyes seemed to hold the secrets of the universe. Alongside her were Oliver, a portly tabby with a penchant for storytelling, Luna, a sleek black cat with a mystical aura, and Jasper, a ginger tom known for his adventurous spirit.
#
# The villagers adored their feline rulers, and in return, the cats ensured that the village thrived. The fields were always bountiful, the weather was fair, and the village was free from misfortune. It was said that the cats had a special connection to the natural world, and their presence kept everything in balance.
#
# One day, a young girl named Elara, with a heart full of curiosity and a mind brimming with questions, decided she wanted to learn the secrets of the Feline Council. She had always been fascinated by the cats and their mysterious ways. With her trusty sketchbook in hand, she set out to observe the council from a distance, hoping to uncover the magic that lay behind their rule.
#
# Elara spent days watching the cats from the shadows, sketching their every move. She noticed how Seraphina would sit atop the ancient stone wall, gazing at the stars as if reading the night sky. Oliver would gather the village children around him, regaling them with tales of old, while Luna would disappear into the forest, only to return with herbs and flowers that seemed to heal any ailment. Jasper, on the other hand, would lead the village cats on daring expeditions, returning with treasures from the world beyond.
#
# As Elara continued her observations, she began to notice something extraordinary. The cats communicated with each other in a language of purrs, meows, and silent glances. It was a language of understanding and harmony, one that transcended words. She realized that the true magic of the Feline Council was not in any supernatural power, but in their ability to listen, to understand, and to care for the world around them.
#
# Inspired by this revelation, Elara approached the council one evening, her heart pounding with excitement and a little fear. To her surprise, the cats welcomed her with gentle purrs and soft nuzzles. Seraphina, with her wise eyes, seemed to nod in approval, as if acknowledging Elara's newfound understanding.
#
# From that day on, Elara became an honorary member of the Feline Council. She learned the art of listening to the world, of understanding the delicate balance of nature, and of caring for the village and its inhabitants. Under her guidance, the bond between the villagers and the cats grew stronger, and Whiskerville flourished like never before.
#
# And so, in the village of Whiskerville, where cats ruled with wisdom and grace, the legacy of the Feline Council lived on, reminding all who lived there of the power of understanding, harmony, and love.
#
# JOKE:
# Why was the cat sitting on the computer?
#
# Because it wanted to keep an eye on the mouse!
#
# POEM:
# In the quiet corners of the night,
# Where moonbeams dance with gentle light,
# A shadow moves with grace and poise,
# A feline form, a silent noise.
#
# With eyes like lanterns, green and gold,
# They hold the secrets, tales untold,
# Whiskers twitch with ancient lore,
# Of lands they've roamed and dreams they store.
#
# Upon the fence, they sit and stare,
# At worlds beyond, with knowing air,
# A symphony of purrs and sighs,
# A lullaby beneath the skies.
#
# Their paws, like velvet, tread the ground,
# In silent steps, they make no sound,
# Yet in their gaze, a universe,
# A mystery, a gentle curse.
#
# Oh, cats, the keepers of the night,
# With playful hearts and spirits light,
# In every leap and bound they take,
# A dance of freedom, wide awake.
#
# So let us cherish, hold them dear,
# These creatures wise, without a fear,
# For in their presence, we may find,
# A touch of magic, undefined.
